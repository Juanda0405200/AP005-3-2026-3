# %%
# Encabezado sobre cómo obtener el valor asociado a una clave.
# #### Get A Key

# %%
# Comentario explicativo sobre cómo acceder a los valores utilizando su clave.
# #you can access the values in it by providing the key:

# %%
# Diccionario 'building_heights' que asigna rascacielos a sus alturas en metros.
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %%
# Imprime el valor asociado a la clave "Burj Khalifa" (828).
# print(building_heights["Burj Khalifa"]) # Prints 828

# %%
# Imprime el valor asociado a la clave "Ping An" (599).
# print(building_heights["Ping An"]) # Prints 599

# %%
# Diccionario 'zodiac_elements' que relaciona elementos del zodiaco con listas de sus signos correspondientes.
# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %%
# Imprime la lista de signos pertenecientes al elemento "earth".
# print(zodiac_elements["earth"])

# %%
# Imprime la lista de signos pertenecientes al elemento "fire".
# print(zodiac_elements["fire"])

# %%
# Encabezado sobre qué ocurre al intentar consultar una clave inexistente.
# ## Get an Invalid Key

# %%
# Redefinición del diccionario 'building_heights'.
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %%
# Intento de acceso a una clave inexistente ("Landmark 81"), lo cual causaría un KeyError.
# print(building_heights["Landmark 81"])

# %%
# Comentario explicativo sobre el uso del operador 'in' para prevenir errores de clave no encontrada.
# ##One way to avoid this error is to first check if the key exists in the dictionary:

# %%
# Define una variable de texto con la clave que se desea validar.
# key_to_check = "Landmark 81"

# %%
# Condicional que evalúa si la clave existe dentro del diccionario antes de acceder a ella.
# if key_to_check in building_heights:

# %%
# Imprime la altura si la clave se encuentra presente.
#   print(building_heights["Landmark 81"])

# %%
# Redefinición del diccionario 'zodiac_elements'.
# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %%
# Asigna un valor de texto a una nueva clave "energy".
# zodiac_elements["energy"] = "Not a Zodiac element"

# %%
# Comprueba si la clave "energy" se encuentra registrada en el diccionario.
# if "energy" in zodiac_elements:

# %%
# Imprime el valor guardado en la clave "energy".
#   print(zodiac_elements["energy"])

# %%
# Encabezado sobre la lectura segura de claves con el método .get().
# ##Safely Get a Key

# %%
# Redefinición del diccionario 'building_heights'.
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %%
# Comentario indicando el valor devuelto en la siguiente operación.
# #this line will return 632:

# %%
# Lee de forma segura la clave "Shanghai Tower" usando .get(), devolviendo 632.
# building_heights.get("Shanghai Tower")

# %%
# Comentario explicativo sobre la respuesta frente a claves inexistentes.
# #this line will return None:

# %%
# Lee la clave "My House" usando .get(), que al no existir devuelve None en lugar de dar error.
# building_heights.get("My House")

# %%
# Diccionario 'user_ids' que asocia nombres de usuario con identificadores numéricos.
# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %%
# Consulta segura del id perteneciente a "teraCoder".
# user_ids.get("teraCoder")

# %%
# Condicional que evalúa si la consulta de "teraCoder" devuelve None.
# if user_ids.get("teraCoder") == None:

# %%
# Asigna un valor por defecto (1000) si el usuario no existe.
#    tc_id = 1000

# %%
# Bloque alternativo si el usuario sí existe.
# else:

# %%
# Asigna a 'tc_id' el valor obtenido del diccionario.
#    tc_id = user_ids.get("teraCoder")

# %%
# Imprime el valor final guardado en 'tc_id'.
# print(tc_id)

# %%
# Condicional que verifica si la clave "superStackSmash" no está en el diccionario.
# if user_ids.get("superStackSmash") == None:

# %%
# Asigna un valor por defecto de 100000 a 'stack_id'.
#      stack_id = 100000

# %%
# Imprime el valor de 'stack_id' en consola.
# print(stack_id)

# %%
# Encabezado sobre cómo eliminar elementos usando el método .pop().
# ###Delete a Key

# %%
# Explicación comentada sobre el funcionamiento del método .pop().
# .pop() works to delete items from a dictionary, when you know the key value.

# %%
# Diccionario 'raffle' con números de boleto como clave y premios como valor.
# raffle = {223842: "Teddy Bear", 872921: "Concert Tickets", 320291: "Gift Basket", 412123: "Necklace", 298787: "Pasta Maker"}

# %%
# Elimina la clave 320291, devolviendo y mostrando "Gift Basket".
# print(raffle.pop(320291, "No Prize"))

# %%
# Comentario con la salida esperada.
# # Prints "Gift Basket"

# %%
# Imprime el estado actual del diccionario sin el elemento eliminado.
# print(raffle)

# %%
# Comentario mostrando el estado del diccionario tras la eliminación.
# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}

# %%
# Intenta eliminar una clave inexistente (100000) devuelviendo el valor por defecto "No Prize".
# print(raffle.pop(100000, "No Prize"))

# %%
# Comentario con la salida esperada.
# # Prints "No Prize"

# %%
# Imprime el diccionario notificando que no sufrió cambios.
# print(raffle)

# %%
# Comentario con la representación del diccionario sin alterar.
# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}

# %%
# Elimina la clave 872921, devolviendo e imprimiendo "Concert Tickets".
# print(raffle.pop(872921, "No Prize"))

# %%
# Comentario con la salida esperada.
# # Prints "Concert Tickets"

# %%
# Imprime el diccionario en consola.
# print(raffle)

# %%
# Comentario con la estructura final del diccionario.
# # Prints {223842: "Teddy Bear", 412123: "Necklace", 298787: "Pasta Maker"}

# %%
# Diccionario 'available_items' con objetos de juego y sus puntos asociados.
# available_items = {"health potion": 10, "cake of the cure": 5, "green elixir": 20, "strength sandwich": 25, "stamina grains": 15, "power stew": 30}

# %%
# Define la variable 'health_points' con un valor base de 20.
# health_points = 20

# %%
# Extrae y elimina "stamina grains" sumando sus puntos (15) a 'health_points'.
# health_points += available_items.pop("stamina grains", 0)

# %%
# Extrae y elimina "power stew" sumando sus puntos (30) a 'health_points'.
# health_points += available_items.pop("power stew", 0)

# %%
# Intenta extraer "mystic bread"; al no existir, suma el valor por defecto (0).
# health_points += available_items.pop("mystic bread", 0)

# %%
# Imprime el diccionario 'available_items' sin los elementos consumidos.
# print(available_items)

# %%
# Imprime el total acumulado de puntos de salud.
# print(health_points)

# %%
# Encabezado sobre cómo obtener todas las claves de un diccionario.
# ##Get All Keys

# %%
# Diccionario 'test_scores' que asocia estudiantes con sus listas de calificaciones.
# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %%
# Convierte las claves del diccionario a una lista e imprime la lista resultante.
# print(list(test_scores))

# %%
# Comentario mostrando la lista resultante devuelta en la consola.
# # Prints ["Grace", "Jeffrey", "Sylvia", "Pedro", "Martin", "Dina"]

# %%
# Bucle for que recorre individualmente las claves devueltas por .keys().
# for student in test_scores.keys():

# %%
# Imprime el nombre de cada estudiante por separado.
#  print(student)

# %%
# Redefinición del diccionario 'user_ids'.
# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %%
# Diccionario 'num_exercises' relacionando temas con número de ejercicios.
# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %%
# Obtiene la vista de claves dict_keys con todos los usuarios.
# users = user_ids.keys()

# %%
# Obtiene la vista de claves dict_keys con todas las lecciones.
# lessons = num_exercises.keys()

# %%
# Imprime el objeto dict_keys de usuarios.
# print(users)

# %%
# Imprime el objeto dict_keys de lecciones.
# print(lessons)

# %%
# Encabezado sobre cómo obtener todos los valores del diccionario.
##Get All Values

# %%
# Redefinición del diccionario 'test_scores'.
# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %%
# Bucle for que itera a través de los valores (listas de notas) usando .values().
# for score_list in test_scores.values():

# %%
# Imprime la lista de calificaciones de cada estudiante.
#  print(score_list)

# %%
# Redefinición del diccionario 'num_exercises'.
# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %%
# Inicializa el acumulador 'total_exercises' en cero.
# total_exercises = 0

# %%
# Bucle for para iterar por las cantidades numéricas devueltas por .values().
# for exercises in num_exercises.values():

# %%
# Suma el número de ejercicios de cada tema al total acumulado.
#   total_exercises += exercises

# %%
# Imprime la suma total de ejercicios.
# print(total_exercises)

# %%
# Encabezado sobre cómo obtener pares clave-valor usando .items().
##Get All Items

# %%
# Diccionario 'biggest_brands' que relaciona marcas con su valor en miles de millones.
# biggest_brands = {"Apple": 184, "Google": 141.7, "Microsoft": 80, "Coca-Cola": 69.7, "Amazon": 64.8}

# %%
# Bucle que desempaqueta simultáneamente cada clave ('company') y valor ('value') devueltos por .items().
# for company, value in biggest_brands.items():

# %%
# Imprime una frase formateada combinando la empresa y su valor traducido a string.
#  print(company + " has a value of " + str(value) + " billion dollars. ")

# %%
# Diccionario 'pct_women_in_occupation' con porcentajes de mujeres por ocupación.
# pct_women_in_occupation = {"CEO": 28, "Engineering Manager": 9, "Pharmacist": 58, "Physician": 40, "Lawyer": 37, "Aerospace Engineer": 9}

# %%
# Bucle for que desempaqueta la ocupación y su porcentaje mediante .items().
# for occupation, percentage in pct_women_in_occupation.items():

# %%
# Imprime una frase estructurada mostrando la ocupación y el porcentaje correspondiente.
#   print("Women make up " + str(percentage) + " percent of " + occupation + "s.")
