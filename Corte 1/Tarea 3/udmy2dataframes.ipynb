# %%
import pandas as pd

# %%
numbers = [1, 2, 3, 4, 5, 6]

# %% [markdown]
# //Define una lista de números enteros del 1 al 6 y la guarda en la variable

# %%
pd.DataFrame(numbers)

# %% [markdown]
# //Crea y muestra un DataFrame de Pandas a partir de la lista unidimensional

# %%
data = [["Jhon",  23], ["Mary", 18], ["Jhon", 31]]

# %% [markdown]
# Define una lista anidada con pares de datos [nombre, edad] y la guarda en 'data'

# %%
pd.DataFrame(data)

# %% [markdown]
# //Crea y muestra un DataFrame bidimensional a partir de la lista anidada 'data' (columnas indexadas numéricamente 0 y 1)

# %%
pd.DataFrame(data, columns = ["name", "age"])

# %% [markdown]
# //Crea un DataFrame usando 'data' asignando nombres explícitos a las columnas mediante el argumento columns=['name', 'age']
