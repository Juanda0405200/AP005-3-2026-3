# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta.head()

# %% [markdown]
# //muestra 5 filas

# %%
insta.info()

# %% [markdown]
# //muestra un resumen

# %%
insta = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv")
insta

# %% [markdown]
# //guarda los datos de instagram y los muestra

# %%
insta["reg date"] = pd.to_datetime(insta["reg date"])
insta

# %% [markdown]
# //transforma la cadena de cada fila de la columna reg date

# %%
insta.info()

# %% [markdown]
# //muestra un resumen de insta

# %%
insta["last login"] = pd.to_datetime(insta["last login"])
#insta.drop("last login", axis = 1, inplace = True)
insta.info()

# %% [markdown]
# //transforma los datos de last login a fecha tiempo

# %%
insta["gender"].nunique()

# %% [markdown]
# //muestra la cantidad de valores diferentes

# %%
insta.info()

# %% [markdown]
# //muestra un resumen de insta

# %%
insta["gender"].astype("category")

# %% [markdown]
# //transforma gender a category optimizando la memoria

# %%
insta["gender"] = insta["gender"].astype("category")
insta.info()

# %% [markdown]
# //tranforma de forma definitiva gender

# %%
insta["Country"]

# %% [markdown]
# //muestra la columna country
