# %%
import pandas as pd
emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")
emp.head()

# %%
emp.info()

# %% [markdown]
# //Muestra el resumen de la información del DataFrame (tipos de datos, memoria y valores no nulos)

# %%
emp.nunique()

# %% [markdown]
# //Cuenta el número de valores únicos que existen en cada una de las columnas del DataFrame

# %%
emp[["department", "position"]] = emp[["department", "position"]].astype("category")

# %% [markdown]
# //Convierte el tipo de dato de las columnas 'department' y 'position' a tipo categórico ('category') para optimizar memoria

# %%
emp.info()

# %% [markdown]
# //Muestra la información del DataFrame para verificar los nuevos tipos de datos y la reducción de memoria

# %%
"happy".upper()
"PYTHON".lower()

# %% [markdown]
# //Ejemplo en Python nativo: convierte la cadena "happy" a mayúsculas ("HAPPY")
# //Ejemplo en Python nativo: convierte la cadena "PYTHON" a minúsculas ("python")

# %%
emp["name"]
emp["name"].str.lower().str.title()

# %% [markdown]
# //selecciona y muestra la columna 'name' del DataFrame
# //Convierte los nombres a minúsculas y luego aplica formato de título (primera letra de cada palabra en mayúscula)
