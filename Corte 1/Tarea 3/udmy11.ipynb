# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# //conecta el drive del usuario

# %%
nba.head(10)

# %% [markdown]
# //muestra 10 filas

# %%
nba.fillna(0)

# %% [markdown]
# // remplaza temporalmente los valores nulos por un 0

# %%
nba[["College"]].fillna(0, inplace = True)
nba

# %% [markdown]
# //remplaza los valores nulos permanentemente en una copia de la columna

# %%
nba["Name"].fillna("Missing name", inplace = True)
nba

# %% [markdown]
# //remplaza los valores nulos por missing name en una columna aparte
