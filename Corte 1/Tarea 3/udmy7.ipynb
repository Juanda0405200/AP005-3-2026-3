# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %%
nba["Teams"] = " "
nba["nba Teams"] = " "
nba.head()

# %% [markdown]
# //crea dos columnas nuevas

# %%
#nba.Name
#nba.nba Teams
nba.Teams
#nba.Sports

# %% [markdown]
# //muestra las columnas y en este caso la columna team esta vacia

# %%
nba["Sports"] = "basket"
nba.head()

# %% [markdown]
# //Crea una nueva columna que solo tiene basket en cada uno de sus registros

# %%
nba.drop("Teams", axis = 1, inplace = True)
#nba.insert(2, column = "Teams", value = "Colombians")
#nba.insert(2, column = "Sportss", value = "Turmequé")
nba

# %% [markdown]
# //elimina la columna teams y muestra ejemplos para agregar registros en posiciones especificas

# %%
nba

# %% [markdown]
# //muestra la tabla

# %%
nba.insert(2, column = "Teams", value = "Colombians")

# %% [markdown]
# //creo una columna en la posicion 2 y lleno los registros con colomnians
