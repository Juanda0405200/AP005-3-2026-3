# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# //Conecta el drive del usuario

# %%
nba["Salary"]

# %% [markdown]
# // muestra la columna salary

# %%
nba["Salary"].add(50000)

# %% [markdown]
# //suma 50000 a cada regristro de salary conservando los nan intactos

# %%
nba["Salary"] + 2000000

# %% [markdown]
# //suma 2000000 dejando intacto los nan

# %%
nba["bonus_salary"] = nba["Salary"] + 30000
nba

# %% [markdown]
# //Creo otra columna en la cual suma salary y 30000

# %%
nba["Salary"].sub(55000)
#nba["Salary"] - sub(55000)

# %% [markdown]
# //resta 55000 a salary en cada fila menos los nan

# %%
nba["Salary"].div(1000000)
#nba["Salary"]/1000000

# %% [markdown]
# //divide la cantidad de salary entre 100000
