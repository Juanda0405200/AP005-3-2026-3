# %%
import pandas as pd
nba = pd.read_excel("/content/drive/MyDrive/udmy/AP005320241/Nba Teams.xlsx")
nba.head()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# //conecta el drive del usuario

# %%
from google.colab import drive
drive.mount('/content/drive')
nba.head(10)

# %% [markdown]
# //conecta el drive y muestras 10 registros o filas

# %%
nba.tail()

# %% [markdown]
# //Muestra los ultimos valores

# %%
nbaNoNull = nba.dropna()
nbaNoNull

# %% [markdown]
# //elimina las filas que tengan valores nulos y muestra el nuevo cuadro

# %%
nba

# %% [markdown]
# //muestra el cuadro completo

# %%
#nba.dropna(inplace=True)
nba.dropna()
nba

# %% [markdown]
# //Elimina temporalmente las filas con valores nulos

# %%
nba.info()

# %% [markdown]
# //muestra un resumen de nba

# %%
nba

# %% [markdown]
# //muestra la tabla nba

# %%
nba.dropna(how="all")

# %% [markdown]
# // elimina las filas donde todos sus valores sean nulos

# %%
nba.dropna(axis = 0)

# %% [markdown]
# //elimina cualquier fila que tenga valores nulos

# %%
nba.dropna(axis=1)

# %% [markdown]
# //elimina las columnas que tenga valores nulos

# %%
nba.dropna(subset = ["Name", "Salary", "College"])

# %% [markdown]
# //elimina las
