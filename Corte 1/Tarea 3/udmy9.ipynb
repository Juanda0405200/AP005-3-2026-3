# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')
#nba.tail()
nba

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
//Conecta el drive del usuario con el entorno

# %%
nba.info()

# %% [markdown]
# //muestra in resumen de nba

# %%
nba.isnull()

# %% [markdown]
# //llena lo registros colocando false dodne hay datos y true donde esta vacio

# %%
nba.isnull().sum()

# %% [markdown]
# //suma los valores true=1 false=0
