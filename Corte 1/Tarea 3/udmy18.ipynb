# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta["reg date"] = pd.to_datetime(insta["reg date"])
insta["last login"] = pd.to_datetime(insta["last login"])
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")
insta.info()

# %% [markdown]
# //transforma el reg date y last login a fecha, el gender y country a category y el influencer a boleano

# %%
import pandas as pd

insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")

# %% [markdown]
# //trnasforma las columnas como en la linea anterior

# %%
insta[insta["gender"] == "Male"]
insta[insta["Country"] == "Australia"]

# %% [markdown]
# //filtra la palabra male en gender para solo mostrar lo que tiene male y pasa lo mismo con australia en country

# %%
mask = insta["gender"] == "Female"
insta[mask]

# %% [markdown]
# //crea una mascara que revisa si es female y lo guarda, luego muestra la mascara

# %%
insta[insta["Influencer"] == True]

# %% [markdown]
# //filtra la columna influencer para mostrar solo cuando es true

# %%
mask1 = insta["Country"] != "United States"
insta[mask1]

# %% [markdown]
# //filtra guarda y muestra todas la filas
