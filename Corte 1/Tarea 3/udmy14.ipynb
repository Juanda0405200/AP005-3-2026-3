# %%
import pandas as pd
nba = pd.read_excel("/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx")
nba.head()

# %% [markdown]
# //muestra 5 filas de nba

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# //conecta el drive del usuario

# %%
nba.sort_values("Name").head(20)

# %% [markdown]
# //ordena nba en orden alfabetico siguendo la columna name

# %%
nba.sort_values("Salary")
#nba.sort_values("Salary", ascending = False, inplace = True)

# %% [markdown]
# //ordena nba de menor a mayor siguendo la columna salary

# %%
nba.sort_values(["Team", "Name"])
#nba.sort_values(["Team", "Name"], na_position = 'first')

# %% [markdown]
# //ordena nba teniendo en cuenta primero team
