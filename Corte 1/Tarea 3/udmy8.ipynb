# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %%
nba.drop("Salary", axis = 1)

# %% [markdown]
# //Elimino la columna salary temporalmente

# %%
nba

# %% [markdown]
# //Muestra la tabla completa

# %%
nba.drop("Salary", axis = 1, inplace = True)

# %% [markdown]
# //Elimina la columna salary definitivamente

# %%
nba.drop(["Team", "Division"], axis = 1, inplace = True)

# %% [markdown]
# //Elimina las columnas team y divi
