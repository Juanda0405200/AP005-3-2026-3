# %%
import pandas as pd
nba = pd.read_excel('Nba Teams.xlsx')
nba

# %% [markdown]
# //Guarda en nba la infomacion del excel y muestra nba

# %%
nba.info()

# %% [markdown]
# //Muestra un resumen del contenido en nba

# %%
nba.head()

# %% [markdown]
# //Muestra las primeras 5 filas de nba

# %%
nba.head(5).info()

# %% [markdown]
# //Muestra un resumen de las primeras 5 filas
