# %%
import pandas as pd
nba = pd.read_excel("Nba Teams.xlsx")
nba.head()

# %% [markdown]
# //Guarda la info del excel en nba y muetras los 5 primeros registros

# %%
nba[["Name", "Team"]]

# %% [markdown]
# //muestra la columna name y team

# %%
nba[["Name", "Team", "Salary"]]

# %% [markdown]
# //muestra las columnas name team y salary
