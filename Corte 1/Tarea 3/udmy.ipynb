# %%
import pandas as pd
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"
#covid = pd.read_csv(url)
covid = pd.read_csv(url)
covid.head()

# %% [markdown]
# //-Lee los datos desde la URL del archivo CSV y los carga en un DataFrame llamado 'covid'.
# //Muestra las primeras 5 filas del DataFrame 'covid' para inspeccionar su contenido inicial.

# %%
covid.info()

# %% [markdown]
# //Muestra un resumen del DataFrame: tipos de datos, cantidad de filas/columnas y uso de memoria.

# %%
covid.to_csv('NYC_covid_cases.csv')

# %% [markdown]
# //Exporta todas las filas y columnas del DataFrame 'covid' a un archivo CSV local llamado 'NYC_covid_cases.csv'.

# %%
covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])

# %% [markdown]
# ## -Exporta al archivo 'NYC1_covid_cases.csv' únicamente las columnas de conteo de casos, hospitalizados y muertes.
