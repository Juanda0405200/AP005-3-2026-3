# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')
nba.head()

# %% [markdown]
# //muestra 5 filas de nba

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# // conecta el drive del usuario

# %%
nba["Team"].value_counts()

# %% [markdown]
# //cuenta y muestra cuantas veces esta repetido cada equipo en la columna team

# %%
#nba["Division"].value_counts()
nba["Division"].value_counts(ascending = True)

# %% [markdown]
# //cuenta la veces que se repite
