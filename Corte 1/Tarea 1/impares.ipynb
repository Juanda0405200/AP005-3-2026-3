# %%
# for i in range (1,21):
#     residual = i%2
#     if residual == 0:
#         print(f'{i} is even')
#     else:
#         #print(f'{i} is odd')
#         print(str(i) + ' is odd')

# for i in range (0,6):
#     result = i**3
#     print(result)

times = input("Enter a number of times: ")
# pide un valor por consola
times = float(times)
# convierte el numero a uno con decimales
times = int(times)
# elimina la parte decimal y solo deja el entero
print(type(times))
# imprime la clase de times
print(times)

if times == 0:
    print("Don't do anything")
else:
    for i in range(1,times+1):
        print("i = ", i)
# confirma que el valor no sea 0 y muestras los valores desde 1 hasta times
# Out:
# Enter a number of times: 5
# <class 'int'>
# 5
# i =  1
# i =  2
# i =  3
# i =  4
# i =  5
