# %%
import random
from matplotlib import pyplot as plt

# Add your code below:
numbers_a = range(1, 13)
# crea una secuencia del 1 al 12
numbers_b = [random.randint(1, 1000) for i in range(12)]
# genera 12 numero aleatorios entre 1 y 1000
plt.plot(numbers_a, numbers_b)
# dibuja un crefico conectando los primero numeros de 1 a 12 y los de 1 a 1000
plt.show()
# muestra el grafico
