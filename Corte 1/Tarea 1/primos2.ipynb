# %%
a = 1
value = input('Ingrese un valor')
value = int(value)

while a == 1:
    for i in range(1,value+1): #Evalúa los números desde 1 hasta value
        conta = 0
        for n in range(1, i+1): #Recorre todos los números desde 1 hasta 'i' para buscar divisores
            residue = i%n # Calcula el resto/residuo de dividir 'i' entre 'n'.
            if residue == 0: # Verifica si la división es exacta
                conta = conta + 1

            # print("i = ", i)
            # print("n = ", n)
            # print("residue = ", residue)
            # print("conta = ", conta)
    if conta == 2:
       print(f'{i} es un primo') # Imprime que el número 'i' es primo.
       print("\n")
    else:
       print(f'{i} NOOO es un primo') # Imprime que el número 'i' NO es primo.
       print("\n")

    print('Do you want to continue?. Press 1 to do that')
    a = input() # Lee la respuesta ingresada por el usuario como texto.
    a = int(a) # Convierte la respuesta a número entero.

    if a != 1:
        break

    value = input('Ingrese un valor')
    value = int(value)
