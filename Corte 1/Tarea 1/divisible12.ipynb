# %%
for i in range(100, 301):
    if (i%12) != 0:
        continue
    print(i)
# Out:
# 108
# 120
# 132
# 144
# 156
# 168
# 180
# 192
# 204
# 216
# 228
# 240
# 252
# 264
# 276
# 288
# 300

# %% [markdown]
# //crea un bucle que va del 100 a 301, luego entre al if donde revisa si es multiplo de 12 en caso de serlo lo imprime pero s
